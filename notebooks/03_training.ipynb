# %%
# Import necessary libraries
import os
import sys

scripts_path = os.path.abspath(os.path.join(os.getcwd(), "../scripts"))
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

file_path = '../results/Performance_DOCS/model_performance.docx'

from Training import train_model

metrics = train_model()
# Out:
# 🔧 Début de l'entraînement des modèles...
#
# 🚀 Entraînement du modèle : Logistic Regression
# ✅ Modèle Logistic Regression entraîné avec succès en 0.02 secondes.
# 📊 Évaluation du modèle : Logistic Regression
# ✅ Metrics for Logistic Regression updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Logistic Regression.
# ✅ Métriques du modèle Logistic Regression : {'F1 Score': np.float64(0.007185843887541543), 'Accuracy': 0.6104395023437775, 'Precision': np.float64(0.0036075036075036075), 'Recall': np.float64(0.8888888888888888), 'Log Loss': 1.4987038890386746, 'AUC': np.float64(0.8824360075622077), 'MCC': np.float64(0.04068687047168713), 'Balanced Accuracy': np.float64(0.7494430324139445), 'Kappa': np.float64(0.004039396899292891), 'Specificity': np.float64(0.6099971759390003), 'F2 Score': np.float64(0.01774937877174299), 'Training Time (seconds)': 0.0183655999135226}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Logistic Regression.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : Decision Tree
# ✅ Modèle Decision Tree entraîné avec succès en 0.10 secondes.
# 📊 Évaluation du modèle : Decision Tree
# ✅ Metrics for Decision Tree updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Decision Tree.
# ✅ Métriques du modèle Decision Tree : {'F1 Score': np.float64(0.0043987118058282934), 'Accuracy': 0.3299087160328481, 'Precision': np.float64(0.0022045508227698605), 'Recall': np.float64(0.9333333333333333), 'Log Loss': 24.152537978380494, 'AUC': np.float64(0.6311417443283442), 'MCC': np.float64(0.02222172024723888), 'Balanced Accuracy': np.float64(0.6311417443283441), 'Kappa': np.float64(0.0012380747531284264), 'Specificity': np.float64(0.328950155323355), 'F2 Score': np.float64(0.01091958505576788), 'Training Time (seconds)': 0.09784639999270439}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Decision Tree.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : Gaussian Naive Bayes
# ✅ Modèle Gaussian Naive Bayes entraîné avec succès en 0.01 secondes.
# 📊 Évaluation du modèle : Gaussian Naive Bayes
# ✅ Metrics for Gaussian Naive Bayes updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Gaussian Naive Bayes.
# ✅ Métriques du modèle Gaussian Naive Bayes : {'F1 Score': np.float64(0.0100643353079814), 'Accuracy': 0.7261304761569097, 'Precision': np.float64(0.005061182651034659), 'Recall': np.float64(0.8777777777777778), 'Log Loss': 6.5468064110822155, 'AUC': np.float64(0.8686452744045937), 'MCC': np.float64(0.05379452201616454), 'Balanced Accuracy': np.float64(0.8018336784963445), 'Kappa': np.float64(0.006932353899202104), 'Specificity': np.float64(0.725889579214911), 'F2 Score': np.float64(0.024735424885716076), 'Training Time (seconds)': 0.007070699939504266}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Gaussian Naive Bayes.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : XGBoost
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\xgboost\core.py:158: UserWarning: [08:36:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ✅ Modèle XGBoost entraîné avec succès en 0.35 secondes.
# 📊 Évaluation du modèle : XGBoost
# ✅ Metrics for XGBoost updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for XGBoost.
# ✅ Métriques du modèle XGBoost : {'F1 Score': np.float64(0.0033974652618720415), 'Accuracy': 0.07986466006414548, 'Precision': np.float64(0.0017016557684218577), 'Recall': np.float64(0.9888888888888889), 'Log Loss': 3.537069890312449, 'AUC': np.float64(0.8880000941353667), 'MCC': np.float64(0.00996952833516886), 'Balanced Accuracy': np.float64(0.5336547663873984), 'Kappa': np.float64(0.0002316179267543017), 'Specificity': np.float64(0.07842064388590794), 'F2 Score': np.float64(0.008450115833048498), 'Training Time (seconds)': 0.3503212999785319}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\XGBoost.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : Random Forest
# ✅ Modèle Random Forest entraîné avec succès en 0.70 secondes.
# 📊 Évaluation du modèle : Random Forest
# ✅ Metrics for Random Forest updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Random Forest.
# ✅ Métriques du modèle Random Forest : {'F1 Score': np.float64(0.0032619923524401513), 'Accuracy': 0.030751066154442605, 'Precision': np.float64(0.0016336606705269464), 'Recall': np.float64(1.0), 'Log Loss': 2.034424361848239, 'AUC': np.float64(0.8648882926982334), 'MCC': np.float64(0.006908073842660779), 'Balanced Accuracy': np.float64(0.5146056904829144), 'Kappa': np.float64(9.543841396841835e-05), 'Specificity': np.float64(0.029211380965828863), 'F2 Score': np.float64(0.008115272943680005), 'Training Time (seconds)': 0.6985702000092715}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Random Forest.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : Gradient Boosting
# ✅ Modèle Gradient Boosting entraîné avec succès en 2.04 secondes.
# 📊 Évaluation du modèle : Gradient Boosting
# ✅ Metrics for Gradient Boosting updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Gradient Boosting.
# ✅ Métriques du modèle Gradient Boosting : {'F1 Score': np.float64(0.003246753246753247), 'Accuracy': 0.0478271596235858, 'Precision': np.float64(0.0016260763516759674), 'Recall': np.float64(0.9777777777777777), 'Log Loss': 4.272756926626313, 'AUC': np.float64(0.7203205897580721), 'MCC': np.float64(0.004568527094772681), 'Balanced Accuracy': np.float64(0.5120638394678214), 'Kappa': np.float64(8.02440447938979e-05), 'Specificity': np.float64(0.04634990115786501), 'F2 Score': np.float64(0.008076654796431586), 'Training Time (seconds)': 2.0424995999783278}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Gradient Boosting.pkl
# ----------------------------------------
#
# 🚀 Entraînement du modèle : Support Vector Machine (SVC)
# ✅ Modèle Support Vector Machine (SVC) entraîné avec succès en 0.13 secondes.
# 📊 Évaluation du modèle : Support Vector Machine (SVC)
# ✅ Metrics for Support Vector Machine (SVC) updated successfully in c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\results\metrics\NearMiss\metrics.json
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Evaluation.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(metrics_data.keys()), y=list(metrics_data.values()), palette="viridis")
# Metrics saved and plots generated for Support Vector Machine (SVC).
# ✅ Métriques du modèle Support Vector Machine (SVC) : {'F1 Score': np.float64(0.01999189517763069), 'Accuracy': 0.8721495788249392, 'Precision': np.float64(0.010118966224531655), 'Recall': np.float64(0.8222222222222222), 'Log Loss': 1.0863820789762366, 'AUC': np.float64(0.9173518936897926), 'MCC': np.float64(0.08247638489660729), 'Balanced Accuracy': np.float64(0.8472255561831247), 'Kappa': np.float64(0.01691141990762768), 'Specificity': np.float64(0.8722288901440272), 'F2 Score': np.float64(0.04822103479734133), 'Training Time (seconds)': 0.13111790001858026}
# 💾 Modèle sauvegardé sous : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\models\Support Vector Machine (SVC).pkl
# ----------------------------------------
#
# 🎉 Processus terminé avec succès.
