# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts')))

from Preprocessing import preprocessing_data

preprocessing_data()
# Out:
# 2024-12-20 18:32:44,431 - INFO - Prétraitement des données commencé.
# 🌐 Chargement des données...
#
# 🔍 **Aperçu des données :**
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
#
# 📊 Dimensions du dataset (lignes, colonnes) : (284807, 31)
#
# 🔑 Colonnes disponibles : ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']
#
# 🧹 Suppression des doublons...
# ✅ Nombre de doublons supprimés : 1081
# ✅ Nombre de lignes après nettoyage : 283726
#
# ✂️ Séparation des caractéristiques et de la colonne cible...
# 🔢 Nombre de caractéristiques : 30
#
# ⚙️ Normalisation des caractéristiques...
#
# ✂️ Division des données en ensembles d'entraînement et de test...
# 📊 Taille de l'ensemble d'entraînement : 226980 lignes
# 📊 Taille de l'ensemble de test : 56746 lignes
# 📊 Distribution des classes Equilibrage :
# Class
# 0    226597
# 1       383
# Name: count, dtype: int64
# 2024-12-20 18:32:50,808 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Preprocessing.py:175: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y, palette="viridis")
# 2024-12-20 18:32:51,110 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 🟢 Application de NearMiss pour équilibrer les classes...
# 2024-12-20 18:32:52,798 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\scripts\Preprocessing.py:175: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y, palette="viridis")
# 2024-12-20 18:32:52,816 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 🔍 Distribution des classes après NearMiss (Ensemble d'entraînement) :
# Class
# 0    383
# 1    383
# Name: count, dtype: int64
# 💾 Enregistrement des fichiers prétraités...
# ✅ Dataset nettoyé enregistré : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\data\processed\cleaned_dataset.csv
# ✅ Fichiers d'entraînement et de test enregistrés dans le dossier : c:\Users\hp\Desktop\Master_SI\IA_Apprentissage_statistique\TP_Realiser\TP_4_ML_CreditCard_Classification\data\processed
#
# 🎉 Prétraitement des données terminé avec succès !
